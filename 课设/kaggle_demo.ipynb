# %% [markdown]
# {'airplane': 0,
#  'automobile': 1,
#  'bird': 2,
#  'cat': 3,
#  'deer': 4,
#  'dog': 5,
#  'frog': 6,
#  'horse': 7,
#  'ship': 8,
#  'truck': 9}

# %%
import torchvision

# 图像增广
IMAGE_SIZE = 32

mean, std = [0.4914, 0.4822, 0.4465], [0.247, 0.243, 0.261]

transform_train = torchvision.transforms.Compose([
    # 在高度和宽度上将图像RESIZE
    torchvision.transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),  # Resize
    torchvision.transforms.RandomCrop(32, padding=4),
    torchvision.transforms.RandomHorizontalFlip(),
#     torchvision.transforms.RandomRotation(20),
    torchvision.transforms.ColorJitter(brightness=0.1,  #随机颜色抖动
                                       contrast=0.1,
                                       saturation=0.1),
    torchvision.transforms.ToTensor(),
    # 标准化图像的每个通道
    torchvision.transforms.Normalize(mean, std)])

# 在测试期间，只对图像执行标准化，以消除评估结果中的随机性。
transform_test = torchvision.transforms.Compose([
    torchvision.transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(mean, std)])

transform_train
# Out:
# Compose(
#     Resize(size=(32, 32), interpolation=bilinear, max_size=None, antialias=warn)
#     RandomCrop(size=(32, 32), padding=4)
#     RandomHorizontalFlip(p=0.5)
#     ColorJitter(brightness=(0.9, 1.1), contrast=(0.9, 1.1), saturation=(0.9, 1.1), hue=None)
#     ToTensor()
#     Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.247, 0.243, 0.261])
# )

# %%
from torchvision import datasets
import torch
from torch.utils.data import DataLoader

torch.manual_seed(1)

# load and transform
train_dataset = datasets.CIFAR10(root='/kaggle/input/cifar10-python', train=True, download=True, transform=transform_train)
validation_dataset = datasets.CIFAR10(root='/kaggle/input/cifar10-python', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=128,shuffle=True, num_workers=4)
validation_loader = torch.utils.data.DataLoader(dataset=validation_dataset, batch_size=128,shuffle=False, num_workers=4)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# 训练数据集信息
print("训练数据集:")
print("批次数量:", len(train_loader))
print("总样本数量:", len(train_loader.dataset))
print("一个批次的数据形状:", next(iter(train_loader))[0].shape)
print("一个批次的标签形状:", next(iter(train_loader))[1].shape)

# 验证数据集信息
print("\n验证数据集:")
print("批次数量:", len(validation_loader))
print("总样本数量:", len(validation_loader.dataset))
print("一个批次的数据形状:", next(iter(validation_loader))[0].shape)
print("一个批次的标签形状:", next(iter(validation_loader))[1].shape)
# Out:
# 训练数据集:
# 批次数量: 391
# 总样本数量: 50000
# 一个批次的数据形状: torch.Size([128, 3, 32, 32])
# 一个批次的标签形状: torch.Size([128])
#
# 验证数据集:
# 批次数量: 79
# 总样本数量: 10000
# 一个批次的数据形状: torch.Size([128, 3, 32, 32])
# 一个批次的标签形状: torch.Size([128])

# %%
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams['font.family'] = 'Microsoft YaHei'


def show_data(img):
    try:
        plt.imshow(img[0])
    except Exception as e:
        print(e)
    print(img[0].shape, img[0].permute(1, 2, 0).shape)
    plt.imshow(img[0].permute(1, 2, 0))
    plt.title('实际标签: ' + str(img[1]))
    plt.show()

# %%
show_data(train_dataset[4564])
# Out:
# Invalid shape (3, 32, 32) for image data
# torch.Size([3, 32, 32]) torch.Size([32, 32, 3])
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38469 (\N{CJK UNIFIED IDEOGRAPH-9645}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26631 (\N{CJK UNIFIED IDEOGRAPH-6807}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 31614 (\N{CJK UNIFIED IDEOGRAPH-7B7E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
show_data(train_dataset[8976])
# Out:
# Invalid shape (3, 32, 32) for image data
# torch.Size([3, 32, 32]) torch.Size([32, 32, 3])

# %%
# 将图像从 PyTorch tensor 转换为 NumPy 数组
def im_convert(tensor):
    img = tensor.cpu().clone().detach().numpy()  # 将张量移动到 CPU 并转换为 NumPy 数组
    img = img.transpose(1, 2, 0)  # 转置通道顺序，从 (C, H, W) 到 (H, W, C)
    img = img * np.array(tuple(mean)) + np.array(tuple(std))  # 根据均值和标准差反标准化
    img = img.clip(0, 1)  # 将像素值截断到 [0, 1] 范围
    return img


# CIPHAR 10 数据集中的10个类别
classes = ('飞机',
           '汽车',
           '鸟',
           '猫',
           '鹿',
           '狗',
           '青蛙',
           '马',
           '船',
           '卡车')

# 在数据上定义一个可迭代对象
data_iterable = iter(validation_loader)
images, labels = next(data_iterable)  # 从第一个包含 100 张图像的批次到下一个批次

# 创建一个 20x10 的图形，每个图像的大小为 2x5
fig = plt.figure(figsize=(20, 10))

# 在我们的验证数据集中绘制 10 张图像
for idx in np.arange(8):
    ax = fig.add_subplot(2, 4, idx + 1, xticks=[], yticks=[])

    # imshow 不能打印张量！
    # 使用 im_convert 函数将张量图像转换为 NumPy 数组，然后 用 imshow 打印图像
    plt.imshow(im_convert(images[idx]))
    ax.set_title(classes[labels[idx].item()])
# Out:
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 29483 (\N{CJK UNIFIED IDEOGRAPH-732B}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 33337 (\N{CJK UNIFIED IDEOGRAPH-8239}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 39134 (\N{CJK UNIFIED IDEOGRAPH-98DE}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 26426 (\N{CJK UNIFIED IDEOGRAPH-673A}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 38738 (\N{CJK UNIFIED IDEOGRAPH-9752}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 34521 (\N{CJK UNIFIED IDEOGRAPH-86D9}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 27773 (\N{CJK UNIFIED IDEOGRAPH-6C7D}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 36710 (\N{CJK UNIFIED IDEOGRAPH-8F66}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 29483 (\N{CJK UNIFIED IDEOGRAPH-732B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 33337 (\N{CJK UNIFIED IDEOGRAPH-8239}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 39134 (\N{CJK UNIFIED IDEOGRAPH-98DE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26426 (\N{CJK UNIFIED IDEOGRAPH-673A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38738 (\N{CJK UNIFIED IDEOGRAPH-9752}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 34521 (\N{CJK UNIFIED IDEOGRAPH-86D9}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 27773 (\N{CJK UNIFIED IDEOGRAPH-6C7D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 36710 (\N{CJK UNIFIED IDEOGRAPH-8F66}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
data_iterable = iter(train_loader)
images, labels = next(data_iterable)

# 创建一个 20x10 的图形，每个图像的大小为 2x5
fig = plt.figure(figsize=(20, 10))

# 在我们的训练数据集中绘制 10 张图像
for idx in np.arange(8):
    ax = fig.add_subplot(2, 4, idx + 1, xticks=[], yticks=[])

    # imshow 不能打印张量！
    # 使用 im_convert 函数将张量图像转换为 NumPy 数组，然后 用 imshow 打印图像
    plt.imshow(im_convert(images[idx]))
    ax.set_title(classes[labels[idx].item()])
# Out:
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 40575 (\N{CJK UNIFIED IDEOGRAPH-9E7F}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 40479 (\N{CJK UNIFIED IDEOGRAPH-9E1F}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 39532 (\N{CJK UNIFIED IDEOGRAPH-9A6C}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 21345 (\N{CJK UNIFIED IDEOGRAPH-5361}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 29399 (\N{CJK UNIFIED IDEOGRAPH-72D7}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 40575 (\N{CJK UNIFIED IDEOGRAPH-9E7F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 40479 (\N{CJK UNIFIED IDEOGRAPH-9E1F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 39532 (\N{CJK UNIFIED IDEOGRAPH-9A6C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21345 (\N{CJK UNIFIED IDEOGRAPH-5361}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 29399 (\N{CJK UNIFIED IDEOGRAPH-72D7}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
train_dataset.classes
# Out:
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %%
train_dataset.class_to_idx
# Out:
# {'airplane': 0,
#  'automobile': 1,
#  'bird': 2,
#  'cat': 3,
#  'deer': 4,
#  'dog': 5,
#  'frog': 6,
#  'horse': 7,
#  'ship': 8,
#  'truck': 9}

# %%
import torch.nn as nn
import torch.nn.functional as F


class CNN_V1(nn.Module):
    """
    添加一个隐藏层、调整 dropout 值、增加一个卷积层
    总共 3 个隐藏层、3 个卷积层和批量归一化
    """

    # 构造函数
    def __init__(self, out_1=32, out_2=64, out_3=128, number_of_classes=10, p=0):
        super(CNN_V1, self).__init__()

        # 第一个卷积层
        self.cnn1 = nn.Conv2d(in_channels=3, out_channels=out_1, kernel_size=5, padding=2)
        self.conv1_bn = nn.BatchNorm2d(out_1)
        self.maxpool1 = nn.MaxPool2d(kernel_size=2)
        self.drop_conv = nn.Dropout(p=0.2)

        # 第二个卷积层
        self.cnn2 = nn.Conv2d(in_channels=out_1, out_channels=out_2, kernel_size=5, padding=2)
        self.conv2_bn = nn.BatchNorm2d(out_2)
        self.maxpool2 = nn.MaxPool2d(kernel_size=2)

        # 第三个卷积层
        self.cnn3 = nn.Conv2d(in_channels=out_2, out_channels=out_3, kernel_size=5, padding=2)
        self.conv3_bn = nn.BatchNorm2d(out_3)
        self.maxpool3 = nn.MaxPool2d(kernel_size=2)

        # 隐藏层 1
        self.fc1 = nn.Linear(out_3 * 4 * 4, 1000)
        self.fc1_bn = nn.BatchNorm1d(1000)
        self.drop = nn.Dropout(p=p)

        # 隐藏层 2
        self.fc2 = nn.Linear(1000, 1000)
        self.fc2_bn = nn.BatchNorm1d(1000)

        # 隐藏层 3
        self.fc3 = nn.Linear(1000, 1000)
        self.fc3_bn = nn.BatchNorm1d(1000)

        # 隐藏层 4
        self.fc4 = nn.Linear(1000, 1000)
        self.fc4_bn = nn.BatchNorm1d(1000)

        # 最终输出层
        self.fc5 = nn.Linear(1000, number_of_classes)
        self.fc5_bn = nn.BatchNorm1d(number_of_classes)

    # 前向传播
    def forward(self, x):
        x = self.cnn1(x)
        x = self.conv1_bn(x)
        x = F.relu(x)
        x = self.maxpool1(x)
        x = self.drop_conv(x)

        x = self.cnn2(x)
        x = self.conv2_bn(x)
        x = F.relu(x)
        x = self.maxpool2(x)
        x = self.drop_conv(x)

        x = self.cnn3(x)
        x = self.conv3_bn(x)
        x = F.relu(x)
        x = self.maxpool3(x)
        x = self.drop_conv(x)

        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        x = self.fc1_bn(x)
        x = F.relu(self.drop(x))

        x = self.fc2(x)
        x = self.fc2_bn(x)
        x = F.relu(self.drop(x))

        x = self.fc3(x)
        x = self.fc3_bn(x)
        x = F.relu(self.drop(x))

        x = self.fc4(x)
        x = self.fc4_bn(x)
        x = F.relu(self.drop(x))

        x = self.fc5(x)
        x = self.fc5_bn(x)

        return x


model = CNN_V1(out_1=32, out_2=64, out_3=128, number_of_classes=10, p=0.5)
model
# Out:
# CNN_V1(
#   (cnn1): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv1_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (drop_conv): Dropout(p=0.2, inplace=False)
#   (cnn2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv2_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (cnn3): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv3_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=2048, out_features=1000, bias=True)
#   (fc1_bn): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=1000, out_features=1000, bias=True)
#   (fc2_bn): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=1000, out_features=1000, bias=True)
#   (fc3_bn): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc4): Linear(in_features=1000, out_features=1000, bias=True)
#   (fc4_bn): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc5): Linear(in_features=1000, out_features=10, bias=True)
#   (fc5_bn): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
def train_model(model, train_loader, validation_loader, optimizer, criterion, n_epochs=20):
    """
    训练和验证模型

    参数：
    - model: 要训练的模型
    - train_loader: 训练数据加载器
    - validation_loader: 验证数据加载器
    - optimizer: 优化器
    - criterion: 损失函数
    - n_epochs: 训练的轮数

    返回：
    - accuracy_list: 每个轮次的验证准确度列表
    - train_cost_list: 每个轮次的训练损失列表
    - val_cost_list: 每个轮次的验证损失列表
    """

    # 全局变量
    N_test = len(validation_loader.dataset)
    accuracy_list = []
    model = model.to(device)
    train_cost_list = []
    val_cost_list = []
    best_accuracy = 0.0  # 用于保存最佳测试集准确率
    best_model_state = None  # 用于保存最佳测试集准确率对应的模型参数

    for epoch in range(n_epochs):
        train_COST = 0
        for x, y in train_loader:
            x = x.to(device)
            y = y.to(device)
            model.train()
            optimizer.zero_grad()
            z = model(x)
            loss = criterion(z, y)
            loss.backward()
            optimizer.step()
            train_COST += loss.item()

        train_COST = train_COST / len(train_loader)
        train_cost_list.append(train_COST)
        correct = 0

        # 在验证数据上进行预测
        val_COST = 0
        for x_test, y_test in validation_loader:
            model.eval()
            x_test = x_test.to(device)
            y_test = y_test.to(device)
            z = model(x_test)
            val_loss = criterion(z, y_test)
            _, yhat = torch.max(z.data, 1)
            correct += yhat.eq(y_test).sum().item()
            val_COST += val_loss.item()

        val_COST = val_COST / len(validation_loader)
        val_cost_list.append(val_COST)

        accuracy = correct / N_test
        accuracy_list.append(accuracy)

        print("--> Epoch Number : {}".format(epoch + 1),
              " | Training Loss : {}".format(round(train_COST, 4)),
              " | Validation Loss : {}".format(round(val_COST, 4)),
              " | Validation Accuracy : {}%".format(round(accuracy * 100, 2)))

        # 保存最佳测试集准确率对应的模型参数
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_model_state = model.state_dict()

    # 返回最佳测试集准确率对应的模型参数
    return best_accuracy, best_model_state, accuracy_list, train_cost_list, val_cost_list

# %%
criterion = nn.CrossEntropyLoss()
learning_rate = 0.1
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)

# Train the model
best_accuracy, best_model_state, accuracy_list, train_cost_list, val_cost_list = train_model(model=model,
                                                                                             n_epochs=200,
                                                                                             train_loader=train_loader,
                                                                                             validation_loader=validation_loader,
                                                                                             optimizer=optimizer,
                                                                                             criterion=criterion)
# Out:
# --> Epoch Number : 1  | Training Loss : 1.2994  | Validation Loss : 0.9925  | Validation Accuracy : 63.85%
# --> Epoch Number : 2  | Training Loss : 1.1172  | Validation Loss : 0.8845  | Validation Accuracy : 68.87%
# --> Epoch Number : 3  | Training Loss : 1.0107  | Validation Loss : 0.7997  | Validation Accuracy : 72.15%
# --> Epoch Number : 4  | Training Loss : 0.9404  | Validation Loss : 0.7567  | Validation Accuracy : 73.69%
# --> Epoch Number : 5  | Training Loss : 0.8902  | Validation Loss : 0.7275  | Validation Accuracy : 74.69%
# --> Epoch Number : 6  | Training Loss : 0.8446  | Validation Loss : 0.7181  | Validation Accuracy : 75.14%
# --> Epoch Number : 7  | Training Loss : 0.8065  | Validation Loss : 0.6282  | Validation Accuracy : 78.67%
# --> Epoch Number : 8  | Training Loss : 0.7788  | Validation Loss : 0.6213  | Validation Accuracy : 78.52%
# --> Epoch Number : 9  | Training Loss : 0.7581  | Validation Loss : 0.6021  | Validation Accuracy : 79.55%
# --> Epoch Number : 10  | Training Loss : 0.7364  | Validation Loss : 0.6176  | Validation Accuracy : 78.52%
# --> Epoch Number : 11  | Training Loss : 0.7193  | Validation Loss : 0.5607  | Validation Accuracy : 80.59%
# --> Epoch Number : 12  | Training Loss : 0.6953  | Validation Loss : 0.5935  | Validation Accuracy : 79.57%
# --> Epoch Number : 13  | Training Loss : 0.6858  | Validation Loss : 0.5806  | Validation Accuracy : 79.9%
# --> Epoch Number : 14  | Training Loss : 0.6718  | Validation Loss : 0.5563  | Validation Accuracy : 81.09%
# --> Epoch Number : 15  | Training Loss : 0.6606  | Validation Loss : 0.5502  | Validation Accuracy : 81.55%
# --> Epoch Number : 16  | Training Loss : 0.6474  | Validation Loss : 0.5167  | Validation Accuracy : 82.25%
# --> Epoch Number : 17  | Training Loss : 0.6419  | Validation Loss : 0.5186  | Validation Accuracy : 82.02%
# --> Epoch Number : 18  | Training Loss : 0.6255  | Validation Loss : 0.5224  | Validation Accuracy : 82.12%
# --> Epoch Number : 19  | Training Loss : 0.6161  | Validation Loss : 0.4939  | Validation Accuracy : 82.87%
# --> Epoch Number : 20  | Training Loss : 0.6099  | Validation Loss : 0.4942  | Validation Accuracy : 82.58%
# --> Epoch Number : 21  | Training Loss : 0.6021  | Validation Loss : 0.4979  | Validation Accuracy : 83.08%
# --> Epoch Number : 22  | Training Loss : 0.5946  | Validation Loss : 0.4726  | Validation Accuracy : 83.99%
# --> Epoch Number : 23  | Training Loss : 0.5859  | Validation Loss : 0.4823  | Validation Accuracy : 83.71%
# --> Epoch Number : 24  | Training Loss : 0.5825  | Validation Loss : 0.4774  | Validation Accuracy : 83.54%
# --> Epoch Number : 25  | Training Loss : 0.5749  | Validation Loss : 0.4945  | Validation Accuracy : 82.68%
# --> Epoch Number : 26  | Training Loss : 0.569  | Validation Loss : 0.4682  | Validation Accuracy : 83.92%
# --> Epoch Number : 27  | Training Loss : 0.5624  | Validation Loss : 0.4689  | Validation Accuracy : 83.94%
# --> Epoch Number : 28  | Training Loss : 0.552  | Validation Loss : 0.4605  | Validation Accuracy : 84.13%
# --> Epoch Number : 29  | Training Loss : 0.5512  | Validation Loss : 0.4672  | Validation Accuracy : 84.34%
# --> Epoch Number : 30  | Training Loss : 0.5455  | Validation Loss : 0.4513  | Validation Accuracy : 84.74%
# --> Epoch Number : 31  | Training Loss : 0.538  | Validation Loss : 0.4446  | Validation Accuracy : 84.99%
# --> Epoch Number : 32  | Training Loss : 0.5328  | Validation Loss : 0.4547  | Validation Accuracy : 84.14%
# --> Epoch Number : 33  | Training Loss : 0.5321  | Validation Loss : 0.4593  | Validation Accuracy : 84.47%
# --> Epoch Number : 34  | Training Loss : 0.5206  | Validation Loss : 0.4467  | Validation Accuracy : 84.76%
# --> Epoch Number : 35  | Training Loss : 0.5208  | Validation Loss : 0.4382  | Validation Accuracy : 84.86%
# --> Epoch Number : 36  | Training Loss : 0.5177  | Validation Loss : 0.4478  | Validation Accuracy : 84.65%
# --> Epoch Number : 37  | Training Loss : 0.5118  | Validation Loss : 0.4343  | Validation Accuracy : 85.07%
# --> Epoch Number : 38  | Training Loss : 0.5016  | Validation Loss : 0.4256  | Validation Accuracy : 85.45%
# --> Epoch Number : 39  | Training Loss : 0.5067  | Validation Loss : 0.4256  | Validation Accuracy : 85.57%
# --> Epoch Number : 40  | Training Loss : 0.5059  | Validation Loss : 0.4182  | Validation Accuracy : 85.23%
# --> Epoch Number : 41  | Training Loss : 0.4981  | Validation Loss : 0.4129  | Validation Accuracy : 85.71%
# --> Epoch Number : 42  | Training Loss : 0.493  | Validation Loss : 0.4309  | Validation Accuracy : 85.36%
# --> Epoch Number : 43  | Training Loss : 0.4862  | Validation Loss : 0.4255  | Validation Accuracy : 85.71%
# --> Epoch Number : 44  | Training Loss : 0.4891  | Validation Loss : 0.4279  | Validation Accuracy : 85.21%
# --> Epoch Number : 45  | Training Loss : 0.4757  | Validation Loss : 0.4183  | Validation Accuracy : 85.81%
# --> Epoch Number : 46  | Training Loss : 0.4839  | Validation Loss : 0.4063  | Validation Accuracy : 85.79%
# --> Epoch Number : 47  | Training Loss : 0.4826  | Validation Loss : 0.4023  | Validation Accuracy : 86.15%
# --> Epoch Number : 48  | Training Loss : 0.4714  | Validation Loss : 0.4366  | Validation Accuracy : 85.05%
# --> Epoch Number : 49  | Training Loss : 0.4706  | Validation Loss : 0.4089  | Validation Accuracy : 85.99%
# --> Epoch Number : 50  | Training Loss : 0.4703  | Validation Loss : 0.4221  | Validation Accuracy : 85.9%
# --> Epoch Number : 51  | Training Loss : 0.467  | Validation Loss : 0.4182  | Validation Accuracy : 85.84%
# --> Epoch Number : 52  | Training Loss : 0.4583  | Validation Loss : 0.4056  | Validation Accuracy : 86.34%
# --> Epoch Number : 53  | Training Loss : 0.4607  | Validation Loss : 0.4132  | Validation Accuracy : 86.02%
# --> Epoch Number : 54  | Training Loss : 0.4606  | Validation Loss : 0.3985  | Validation Accuracy : 86.39%
# --> Epoch Number : 55  | Training Loss : 0.4592  | Validation Loss : 0.4206  | Validation Accuracy : 85.75%
# --> Epoch Number : 56  | Training Loss : 0.4532  | Validation Loss : 0.402  | Validation Accuracy : 86.32%
# --> Epoch Number : 57  | Training Loss : 0.4527  | Validation Loss : 0.4041  | Validation Accuracy : 86.32%
# --> Epoch Number : 58  | Training Loss : 0.4538  | Validation Loss : 0.4144  | Validation Accuracy : 85.91%
# --> Epoch Number : 59  | Training Loss : 0.4446  | Validation Loss : 0.4196  | Validation Accuracy : 86.09%
# --> Epoch Number : 60  | Training Loss : 0.4412  | Validation Loss : 0.4148  | Validation Accuracy : 85.98%
# --> Epoch Number : 61  | Training Loss : 0.4427  | Validation Loss : 0.3946  | Validation Accuracy : 86.55%
# --> Epoch Number : 62  | Training Loss : 0.443  | Validation Loss : 0.3969  | Validation Accuracy : 86.26%
# --> Epoch Number : 63  | Training Loss : 0.4318  | Validation Loss : 0.3866  | Validation Accuracy : 86.8%
# --> Epoch Number : 64  | Training Loss : 0.4316  | Validation Loss : 0.408  | Validation Accuracy : 86.41%
# --> Epoch Number : 65  | Training Loss : 0.4354  | Validation Loss : 0.3803  | Validation Accuracy : 86.9%
# --> Epoch Number : 66  | Training Loss : 0.4284  | Validation Loss : 0.3873  | Validation Accuracy : 87.04%
# --> Epoch Number : 67  | Training Loss : 0.4318  | Validation Loss : 0.3947  | Validation Accuracy : 86.68%
# --> Epoch Number : 68  | Training Loss : 0.4239  | Validation Loss : 0.3878  | Validation Accuracy : 87.09%
# --> Epoch Number : 69  | Training Loss : 0.4226  | Validation Loss : 0.3909  | Validation Accuracy : 86.76%
# --> Epoch Number : 70  | Training Loss : 0.4167  | Validation Loss : 0.3857  | Validation Accuracy : 86.94%
# --> Epoch Number : 71  | Training Loss : 0.4246  | Validation Loss : 0.3832  | Validation Accuracy : 87.19%
# --> Epoch Number : 72  | Training Loss : 0.4158  | Validation Loss : 0.3963  | Validation Accuracy : 86.31%
# --> Epoch Number : 73  | Training Loss : 0.4227  | Validation Loss : 0.3982  | Validation Accuracy : 86.31%
# --> Epoch Number : 74  | Training Loss : 0.4134  | Validation Loss : 0.3966  | Validation Accuracy : 86.7%
# --> Epoch Number : 75  | Training Loss : 0.4137  | Validation Loss : 0.3918  | Validation Accuracy : 86.91%
# --> Epoch Number : 76  | Training Loss : 0.4148  | Validation Loss : 0.3839  | Validation Accuracy : 87.07%
# --> Epoch Number : 77  | Training Loss : 0.3988  | Validation Loss : 0.3928  | Validation Accuracy : 86.89%
# --> Epoch Number : 78  | Training Loss : 0.4058  | Validation Loss : 0.3876  | Validation Accuracy : 86.81%
# --> Epoch Number : 79  | Training Loss : 0.4068  | Validation Loss : 0.3814  | Validation Accuracy : 86.99%
# --> Epoch Number : 80  | Training Loss : 0.4067  | Validation Loss : 0.3988  | Validation Accuracy : 86.42%
# --> Epoch Number : 81  | Training Loss : 0.4  | Validation Loss : 0.3898  | Validation Accuracy : 86.83%
# --> Epoch Number : 82  | Training Loss : 0.3971  | Validation Loss : 0.3896  | Validation Accuracy : 86.97%
# --> Epoch Number : 83  | Training Loss : 0.4011  | Validation Loss : 0.372  | Validation Accuracy : 87.1%
# --> Epoch Number : 84  | Training Loss : 0.4005  | Validation Loss : 0.3819  | Validation Accuracy : 87.08%
# --> Epoch Number : 85  | Training Loss : 0.3911  | Validation Loss : 0.3965  | Validation Accuracy : 86.71%
# --> Epoch Number : 86  | Training Loss : 0.3958  | Validation Loss : 0.3828  | Validation Accuracy : 86.93%
# --> Epoch Number : 87  | Training Loss : 0.3966  | Validation Loss : 0.3785  | Validation Accuracy : 87.24%
# --> Epoch Number : 88  | Training Loss : 0.3892  | Validation Loss : 0.3805  | Validation Accuracy : 86.98%
# --> Epoch Number : 89  | Training Loss : 0.3902  | Validation Loss : 0.3705  | Validation Accuracy : 87.49%
# --> Epoch Number : 90  | Training Loss : 0.3876  | Validation Loss : 0.3827  | Validation Accuracy : 87.31%
# --> Epoch Number : 91  | Training Loss : 0.3875  | Validation Loss : 0.3778  | Validation Accuracy : 87.49%
# --> Epoch Number : 92  | Training Loss : 0.3824  | Validation Loss : 0.3679  | Validation Accuracy : 87.79%
# --> Epoch Number : 93  | Training Loss : 0.38  | Validation Loss : 0.3858  | Validation Accuracy : 87.33%
# --> Epoch Number : 94  | Training Loss : 0.3816  | Validation Loss : 0.3844  | Validation Accuracy : 87.24%
# --> Epoch Number : 95  | Training Loss : 0.3812  | Validation Loss : 0.3679  | Validation Accuracy : 87.35%
# --> Epoch Number : 96  | Training Loss : 0.3798  | Validation Loss : 0.3698  | Validation Accuracy : 87.67%
# --> Epoch Number : 97  | Training Loss : 0.3808  | Validation Loss : 0.37  | Validation Accuracy : 87.56%
# --> Epoch Number : 98  | Training Loss : 0.3739  | Validation Loss : 0.3668  | Validation Accuracy : 87.58%
# --> Epoch Number : 99  | Training Loss : 0.3765  | Validation Loss : 0.3794  | Validation Accuracy : 87.32%
# --> Epoch Number : 100  | Training Loss : 0.3768  | Validation Loss : 0.3785  | Validation Accuracy : 87.51%
# --> Epoch Number : 101  | Training Loss : 0.373  | Validation Loss : 0.3812  | Validation Accuracy : 87.31%
# --> Epoch Number : 102  | Training Loss : 0.3746  | Validation Loss : 0.3683  | Validation Accuracy : 87.69%
# --> Epoch Number : 103  | Training Loss : 0.3714  | Validation Loss : 0.3634  | Validation Accuracy : 87.78%
# --> Epoch Number : 104  | Training Loss : 0.3676  | Validation Loss : 0.3715  | Validation Accuracy : 87.41%
# --> Epoch Number : 105  | Training Loss : 0.3681  | Validation Loss : 0.3702  | Validation Accuracy : 87.38%
# --> Epoch Number : 106  | Training Loss : 0.3681  | Validation Loss : 0.3779  | Validation Accuracy : 87.24%
# --> Epoch Number : 107  | Training Loss : 0.3686  | Validation Loss : 0.3639  | Validation Accuracy : 87.8%
# --> Epoch Number : 108  | Training Loss : 0.3645  | Validation Loss : 0.3639  | Validation Accuracy : 87.73%
# --> Epoch Number : 109  | Training Loss : 0.3662  | Validation Loss : 0.3711  | Validation Accuracy : 87.18%
# --> Epoch Number : 110  | Training Loss : 0.3625  | Validation Loss : 0.3726  | Validation Accuracy : 87.68%
# --> Epoch Number : 111  | Training Loss : 0.3632  | Validation Loss : 0.3651  | Validation Accuracy : 87.79%
# --> Epoch Number : 112  | Training Loss : 0.3601  | Validation Loss : 0.3682  | Validation Accuracy : 87.67%
# --> Epoch Number : 113  | Training Loss : 0.3554  | Validation Loss : 0.3668  | Validation Accuracy : 87.81%
# --> Epoch Number : 114  | Training Loss : 0.3548  | Validation Loss : 0.3595  | Validation Accuracy : 87.97%
# --> Epoch Number : 115  | Training Loss : 0.361  | Validation Loss : 0.3645  | Validation Accuracy : 87.96%
# --> Epoch Number : 116  | Training Loss : 0.3554  | Validation Loss : 0.3738  | Validation Accuracy : 87.76%
# --> Epoch Number : 117  | Training Loss : 0.3621  | Validation Loss : 0.3688  | Validation Accuracy : 87.81%
# --> Epoch Number : 118  | Training Loss : 0.3539  | Validation Loss : 0.3665  | Validation Accuracy : 87.78%
# --> Epoch Number : 119  | Training Loss : 0.3535  | Validation Loss : 0.3778  | Validation Accuracy : 87.49%
# --> Epoch Number : 120  | Training Loss : 0.3502  | Validation Loss : 0.3652  | Validation Accuracy : 87.94%
# --> Epoch Number : 121  | Training Loss : 0.348  | Validation Loss : 0.3735  | Validation Accuracy : 87.64%
# --> Epoch Number : 122  | Training Loss : 0.3538  | Validation Loss : 0.3724  | Validation Accuracy : 87.7%
# --> Epoch Number : 123  | Training Loss : 0.3513  | Validation Loss : 0.3713  | Validation Accuracy : 87.63%
# --> Epoch Number : 124  | Training Loss : 0.351  | Validation Loss : 0.3797  | Validation Accuracy : 87.45%
# --> Epoch Number : 125  | Training Loss : 0.3512  | Validation Loss : 0.358  | Validation Accuracy : 87.99%
# --> Epoch Number : 126  | Training Loss : 0.3437  | Validation Loss : 0.3678  | Validation Accuracy : 87.62%
# --> Epoch Number : 127  | Training Loss : 0.349  | Validation Loss : 0.3684  | Validation Accuracy : 87.58%
# --> Epoch Number : 128  | Training Loss : 0.3521  | Validation Loss : 0.3649  | Validation Accuracy : 87.75%
# --> Epoch Number : 129  | Training Loss : 0.3428  | Validation Loss : 0.3655  | Validation Accuracy : 87.83%
# --> Epoch Number : 130  | Training Loss : 0.3428  | Validation Loss : 0.3667  | Validation Accuracy : 87.83%
# --> Epoch Number : 131  | Training Loss : 0.3394  | Validation Loss : 0.3648  | Validation Accuracy : 87.72%
# --> Epoch Number : 132  | Training Loss : 0.3417  | Validation Loss : 0.3574  | Validation Accuracy : 88.18%
# --> Epoch Number : 133  | Training Loss : 0.3427  | Validation Loss : 0.3644  | Validation Accuracy : 87.86%
# --> Epoch Number : 134  | Training Loss : 0.3448  | Validation Loss : 0.3614  | Validation Accuracy : 87.67%
# --> Epoch Number : 135  | Training Loss : 0.3351  | Validation Loss : 0.3687  | Validation Accuracy : 87.54%
# --> Epoch Number : 136  | Training Loss : 0.34  | Validation Loss : 0.3765  | Validation Accuracy : 87.55%
# --> Epoch Number : 137  | Training Loss : 0.3368  | Validation Loss : 0.3653  | Validation Accuracy : 88.01%
# --> Epoch Number : 138  | Training Loss : 0.3377  | Validation Loss : 0.3665  | Validation Accuracy : 88.05%
# --> Epoch Number : 139  | Training Loss : 0.336  | Validation Loss : 0.3554  | Validation Accuracy : 88.36%
# --> Epoch Number : 140  | Training Loss : 0.3307  | Validation Loss : 0.3813  | Validation Accuracy : 87.53%
# --> Epoch Number : 141  | Training Loss : 0.335  | Validation Loss : 0.3601  | Validation Accuracy : 87.87%
# --> Epoch Number : 142  | Training Loss : 0.3284  | Validation Loss : 0.3609  | Validation Accuracy : 88.17%
# --> Epoch Number : 143  | Training Loss : 0.3361  | Validation Loss : 0.358  | Validation Accuracy : 87.99%
# --> Epoch Number : 144  | Training Loss : 0.3279  | Validation Loss : 0.3631  | Validation Accuracy : 88.01%
# --> Epoch Number : 145  | Training Loss : 0.3332  | Validation Loss : 0.357  | Validation Accuracy : 88.11%
# --> Epoch Number : 146  | Training Loss : 0.3256  | Validation Loss : 0.3677  | Validation Accuracy : 88.11%
# --> Epoch Number : 147  | Training Loss : 0.3298  | Validation Loss : 0.3658  | Validation Accuracy : 87.88%
# --> Epoch Number : 148  | Training Loss : 0.3293  | Validation Loss : 0.3762  | Validation Accuracy : 87.61%
# --> Epoch Number : 149  | Training Loss : 0.3215  | Validation Loss : 0.3695  | Validation Accuracy : 87.79%
# --> Epoch Number : 150  | Training Loss : 0.3259  | Validation Loss : 0.3616  | Validation Accuracy : 87.97%
# --> Epoch Number : 151  | Training Loss : 0.3235  | Validation Loss : 0.3632  | Validation Accuracy : 88.05%
# --> Epoch Number : 152  | Training Loss : 0.3259  | Validation Loss : 0.3515  | Validation Accuracy : 88.23%
# --> Epoch Number : 153  | Training Loss : 0.3233  | Validation Loss : 0.367  | Validation Accuracy : 87.85%
# --> Epoch Number : 154  | Training Loss : 0.3205  | Validation Loss : 0.3746  | Validation Accuracy : 87.82%
# --> Epoch Number : 155  | Training Loss : 0.32  | Validation Loss : 0.3619  | Validation Accuracy : 88.13%
# --> Epoch Number : 156  | Training Loss : 0.3218  | Validation Loss : 0.3756  | Validation Accuracy : 87.82%
# --> Epoch Number : 157  | Training Loss : 0.3184  | Validation Loss : 0.3663  | Validation Accuracy : 88.01%
# --> Epoch Number : 158  | Training Loss : 0.3243  | Validation Loss : 0.3588  | Validation Accuracy : 88.44%
# --> Epoch Number : 159  | Training Loss : 0.3225  | Validation Loss : 0.3578  | Validation Accuracy : 88.14%
# --> Epoch Number : 160  | Training Loss : 0.3178  | Validation Loss : 0.3594  | Validation Accuracy : 88.48%
# --> Epoch Number : 161  | Training Loss : 0.315  | Validation Loss : 0.3717  | Validation Accuracy : 88.02%
# --> Epoch Number : 162  | Training Loss : 0.314  | Validation Loss : 0.3783  | Validation Accuracy : 87.82%
# --> Epoch Number : 163  | Training Loss : 0.3203  | Validation Loss : 0.3605  | Validation Accuracy : 88.26%
# --> Epoch Number : 164  | Training Loss : 0.3142  | Validation Loss : 0.3534  | Validation Accuracy : 88.43%
# --> Epoch Number : 165  | Training Loss : 0.3124  | Validation Loss : 0.3573  | Validation Accuracy : 88.39%
# --> Epoch Number : 166  | Training Loss : 0.316  | Validation Loss : 0.3618  | Validation Accuracy : 88.08%
# --> Epoch Number : 167  | Training Loss : 0.3158  | Validation Loss : 0.3658  | Validation Accuracy : 88.09%
# --> Epoch Number : 168  | Training Loss : 0.3145  | Validation Loss : 0.3636  | Validation Accuracy : 88.12%
# --> Epoch Number : 169  | Training Loss : 0.31  | Validation Loss : 0.3607  | Validation Accuracy : 88.32%
# --> Epoch Number : 170  | Training Loss : 0.3127  | Validation Loss : 0.356  | Validation Accuracy : 88.43%
# --> Epoch Number : 171  | Training Loss : 0.3073  | Validation Loss : 0.3525  | Validation Accuracy : 88.36%
# --> Epoch Number : 172  | Training Loss : 0.3128  | Validation Loss : 0.3537  | Validation Accuracy : 88.35%
# --> Epoch Number : 173  | Training Loss : 0.3133  | Validation Loss : 0.3648  | Validation Accuracy : 88.1%
# --> Epoch Number : 174  | Training Loss : 0.3122  | Validation Loss : 0.3566  | Validation Accuracy : 88.48%
# --> Epoch Number : 175  | Training Loss : 0.3047  | Validation Loss : 0.3546  | Validation Accuracy : 88.28%
# --> Epoch Number : 176  | Training Loss : 0.3043  | Validation Loss : 0.3655  | Validation Accuracy : 88.05%
# --> Epoch Number : 177  | Training Loss : 0.3078  | Validation Loss : 0.3702  | Validation Accuracy : 88.11%
# --> Epoch Number : 178  | Training Loss : 0.307  | Validation Loss : 0.3514  | Validation Accuracy : 88.69%
# --> Epoch Number : 179  | Training Loss : 0.3019  | Validation Loss : 0.3689  | Validation Accuracy : 87.98%
# --> Epoch Number : 180  | Training Loss : 0.3024  | Validation Loss : 0.3615  | Validation Accuracy : 88.21%
# --> Epoch Number : 181  | Training Loss : 0.3068  | Validation Loss : 0.3553  | Validation Accuracy : 88.3%
# --> Epoch Number : 182  | Training Loss : 0.3045  | Validation Loss : 0.3585  | Validation Accuracy : 88.25%
# --> Epoch Number : 183  | Training Loss : 0.3024  | Validation Loss : 0.3601  | Validation Accuracy : 88.32%
# --> Epoch Number : 184  | Training Loss : 0.2986  | Validation Loss : 0.3811  | Validation Accuracy : 87.89%
# --> Epoch Number : 185  | Training Loss : 0.3022  | Validation Loss : 0.357  | Validation Accuracy : 88.37%
# --> Epoch Number : 186  | Training Loss : 0.3023  | Validation Loss : 0.348  | Validation Accuracy : 88.65%
# --> Epoch Number : 187  | Training Loss : 0.2981  | Validation Loss : 0.3673  | Validation Accuracy : 88.09%
# --> Epoch Number : 188  | Training Loss : 0.2984  | Validation Loss : 0.3566  | Validation Accuracy : 88.19%
# --> Epoch Number : 189  | Training Loss : 0.2971  | Validation Loss : 0.3617  | Validation Accuracy : 88.16%
# --> Epoch Number : 190  | Training Loss : 0.2974  | Validation Loss : 0.366  | Validation Accuracy : 88.31%
# --> Epoch Number : 191  | Training Loss : 0.2993  | Validation Loss : 0.354  | Validation Accuracy : 88.17%
# --> Epoch Number : 192  | Training Loss : 0.2998  | Validation Loss : 0.3497  | Validation Accuracy : 88.75%
# --> Epoch Number : 193  | Training Loss : 0.2925  | Validation Loss : 0.3517  | Validation Accuracy : 88.39%
# --> Epoch Number : 194  | Training Loss : 0.2966  | Validation Loss : 0.3578  | Validation Accuracy : 88.36%
# --> Epoch Number : 195  | Training Loss : 0.2936  | Validation Loss : 0.3658  | Validation Accuracy : 88.16%
# --> Epoch Number : 196  | Training Loss : 0.2952  | Validation Loss : 0.3602  | Validation Accuracy : 88.19%
# --> Epoch Number : 197  | Training Loss : 0.296  | Validation Loss : 0.3483  | Validation Accuracy : 88.45%
# --> Epoch Number : 198  | Training Loss : 0.2956  | Validation Loss : 0.3575  | Validation Accuracy : 88.34%
# --> Epoch Number : 199  | Training Loss : 0.2963  | Validation Loss : 0.3619  | Validation Accuracy : 88.32%
# --> Epoch Number : 200  | Training Loss : 0.2961  | Validation Loss : 0.3558  | Validation Accuracy : 88.53%

# %%
best_accuracy
# Out:
# 0.8875

# %%
# 保存模型参数
# 保存最佳模型参数
torch.save(best_model_state, '88.75%_model.pth')

# %%
fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.plot(train_cost_list, color=color)
ax1.set_xlabel('epoch', color=color)
ax1.set_ylabel('total loss', color=color)
ax1.tick_params(axis='y', color=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('accuracy', color=color)
ax2.plot(accuracy_list, color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()

# %%
plt.plot(train_cost_list, 'r', label='Training Loss')
plt.plot(val_cost_list, 'g', label='Validation Loss')
plt.xlabel("Iteration")
plt.title("Loss")
plt.legend()

# %%
import pandas as pd
import seaborn as sn
from sklearn.metrics import confusion_matrix

# 初始化预测和真实标签列表
y_pred = []
y_true = []

# 遍历验证数据集
for x, y in torch.utils.data.DataLoader(dataset=validation_dataset, batch_size=1):
    x = x.to(device)
    y = y.to(device)

    # 模型预测
    with torch.no_grad():
        z = model(x)

    _, yhat = torch.max(z, 1)

    # 将预测结果从 GPU 转移到 CPU 并保存
    pred = yhat.cpu().numpy()
    y_pred.extend(pred)

    # 将真实标签从 GPU 转移到 CPU 并保存
    labels = y.cpu().numpy()
    y_true.extend(labels)

# 构建混淆矩阵
cf_matrix = confusion_matrix(y_true, y_pred)

# 构建混淆矩阵的 DataFrame
df_cm = pd.DataFrame(cf_matrix / np.sum(cf_matrix) * 10, index=[i for i in classes], columns=[i for i in classes])

# 绘制热力图
plt.figure(figsize=(12, 7))
sn.heatmap(df_cm, annot=True)

# 保存热力图为图片
plt.savefig('heatmap.png')
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 39134 (\N{CJK UNIFIED IDEOGRAPH-98DE}) missing from current font.
#   fig.canvas.draw()
# /opt/conda/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 26426 (\N{CJK UNIFIED IDEOGRAPH-673A}) missing from current font.
#   fig.canvas.draw()
# /opt/conda/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 27773 (\N{CJK UNIFIED IDEOGRAPH-6C7D}) missing from current font.
#   fig.canvas.draw()
# /opt/conda/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 36710 (\N{CJK UNIFIED IDEOGRAPH-8F66}) missing from current font.
#   fig.canvas.draw()
# /opt/conda/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 40479 (\N{CJK UNIFIED IDEOGRAPH-9E1F}) missing from current font.
#   fig.canvas.draw()
# /opt/conda/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 29483 (\N{CJK UNIFIED IDEOGRAPH-732B}) missing from current font.
#   fig.canvas.draw()
# /opt/conda/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 40575 (\N{CJK UNIFIED IDEOGRAPH-9E7F}) missing from current font.
#   fig.canvas.draw()
# /opt/conda/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 29399 (\N{CJK UNIFIED IDEOGRAPH-72D7}) missing from current font.
#   fig.canvas.draw()
# /opt/conda/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 38738 (\N{CJK UNIFIED IDEOGRAPH-9752}) missing from current font.
#   fig.canvas.draw()
# /opt/conda/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 34521 (\N{CJK UNIFIED IDEOGRAPH-86D9}) missing from current font.
#   fig.canvas.draw()
# /opt/conda/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 39532 (\N{CJK UNIFIED IDEOGRAPH-9A6C}) missing from current font.
#   fig.canvas.draw()
# /opt/conda/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 33337 (\N{CJK UNIFIED IDEOGRAPH-8239}) missing from current font.
#   fig.canvas.draw()
# /opt/conda/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 21345 (\N{CJK UNIFIED IDEOGRAPH-5361}) missing from current font.
#   fig.canvas.draw()
# /tmp/ipykernel_42/4264288709.py:39: UserWarning: Glyph 39134 (\N{CJK UNIFIED IDEOGRAPH-98DE}) missing from current font.
#   plt.savefig('heatmap.png')
# /tmp/ipykernel_42/4264288709.py:39: UserWarning: Glyph 26426 (\N{CJK UNIFIED IDEOGRAPH-673A}) missing from current font.
#   plt.savefig('heatmap.png')
# /tmp/ipykernel_42/4264288709.py:39: UserWarning: Glyph 27773 (\N{CJK UNIFIED IDEOGRAPH-6C7D}) missing from current font.
#   plt.savefig('heatmap.png')
# /tmp/ipykernel_42/4264288709.py:39: UserWarning: Glyph 36710 (\N{CJK UNIFIED IDEOGRAPH-8F66}) missing from current font.
#   plt.savefig('heatmap.png')
# /tmp/ipykernel_42/4264288709.py:39: UserWarning: Glyph 40479 (\N{CJK UNIFIED IDEOGRAPH-9E1F}) missing from current font.
#   plt.savefig('heatmap.png')
# /tmp/ipykernel_42/4264288709.py:39: UserWarning: Glyph 29483 (\N{CJK UNIFIED IDEOGRAPH-732B}) missing from current font.
#   plt.savefig('heatmap.png')
# /tmp/ipykernel_42/4264288709.py:39: UserWarning: Glyph 40575 (\N{CJK UNIFIED IDEOGRAPH-9E7F}) missing from current font.
#   plt.savefig('heatmap.png')
# /tmp/ipykernel_42/4264288709.py:39: UserWarning: Glyph 29399 (\N{CJK UNIFIED IDEOGRAPH-72D7}) missing from current font.
#   plt.savefig('heatmap.png')
# /tmp/ipykernel_42/4264288709.py:39: UserWarning: Glyph 38738 (\N{CJK UNIFIED IDEOGRAPH-9752}) missing from current font.
#   plt.savefig('heatmap.png')
# /tmp/ipykernel_42/4264288709.py:39: UserWarning: Glyph 34521 (\N{CJK UNIFIED IDEOGRAPH-86D9}) missing from current font.
#   plt.savefig('heatmap.png')
# /tmp/ipykernel_42/4264288709.py:39: UserWarning: Glyph 39532 (\N{CJK UNIFIED IDEOGRAPH-9A6C}) missing from current font.
#   plt.savefig('heatmap.png')
# /tmp/ipykernel_42/4264288709.py:39: UserWarning: Glyph 33337 (\N{CJK UNIFIED IDEOGRAPH-8239}) missing from current font.
#   plt.savefig('heatmap.png')
# /tmp/ipykernel_42/4264288709.py:39: UserWarning: Glyph 21345 (\N{CJK UNIFIED IDEOGRAPH-5361}) missing from current font.
#   plt.savefig('heatmap.png')
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 39134 (\N{CJK UNIFIED IDEOGRAPH-98DE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26426 (\N{CJK UNIFIED IDEOGRAPH-673A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 27773 (\N{CJK UNIFIED IDEOGRAPH-6C7D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 36710 (\N{CJK UNIFIED IDEOGRAPH-8F66}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 40479 (\N{CJK UNIFIED IDEOGRAPH-9E1F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 29483 (\N{CJK UNIFIED IDEOGRAPH-732B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 40575 (\N{CJK UNIFIED IDEOGRAPH-9E7F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 29399 (\N{CJK UNIFIED IDEOGRAPH-72D7}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38738 (\N{CJK UNIFIED IDEOGRAPH-9752}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 34521 (\N{CJK UNIFIED IDEOGRAPH-86D9}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 39532 (\N{CJK UNIFIED IDEOGRAPH-9A6C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 33337 (\N{CJK UNIFIED IDEOGRAPH-8239}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21345 (\N{CJK UNIFIED IDEOGRAPH-5361}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90      1000
#            1       0.94      0.94      0.94      1000
#            2       0.91      0.82      0.86      1000
#            3       0.79      0.75      0.77      1000
#            4       0.85      0.90      0.88      1000
#            5       0.82      0.82      0.82      1000
#            6       0.88      0.94      0.91      1000
#            7       0.94      0.90      0.92      1000
#            8       0.94      0.93      0.94      1000
#            9       0.91      0.93      0.92      1000
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.88     10000
# weighted avg       0.89      0.89      0.88     10000

# %%
# 从验证数据加载器中获取一个批次的数据
data_iterable = iter(validation_loader)
images, labels = next(data_iterable)

# 将图像和标签移动到设备（GPU 或 CPU）
images = images.to(device)
labels = labels.to(device)

# 使用模型进行预测
output = model(images)
_, preds = torch.max(output, 1)

# 创建一个用于显示图像和预测结果的图表
fig = plt.figure(figsize=(25, 5))

# 遍历显示前 20 张图像
for idx in np.arange(20):
    ax = fig.add_subplot(2, 10, idx + 1, xticks=[], yticks=[])

    # 显示图像
    plt.imshow(im_convert(images[idx]))

    # 设置图像标题，使用绿色表示正确预测，红色表示错误预测
    ax.set_title("{} ({})".format(
        str(classes[preds[idx].item()]), str(classes[labels[idx].item()])),
        color=("green" if preds[idx] == labels[idx] else "red"))
# Out:
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 29483 (\N{CJK UNIFIED IDEOGRAPH-732B}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 33337 (\N{CJK UNIFIED IDEOGRAPH-8239}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 39134 (\N{CJK UNIFIED IDEOGRAPH-98DE}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 26426 (\N{CJK UNIFIED IDEOGRAPH-673A}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 38738 (\N{CJK UNIFIED IDEOGRAPH-9752}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 34521 (\N{CJK UNIFIED IDEOGRAPH-86D9}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 27773 (\N{CJK UNIFIED IDEOGRAPH-6C7D}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 36710 (\N{CJK UNIFIED IDEOGRAPH-8F66}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 21345 (\N{CJK UNIFIED IDEOGRAPH-5361}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 29399 (\N{CJK UNIFIED IDEOGRAPH-72D7}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 39532 (\N{CJK UNIFIED IDEOGRAPH-9A6C}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 29483 (\N{CJK UNIFIED IDEOGRAPH-732B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 33337 (\N{CJK UNIFIED IDEOGRAPH-8239}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 39134 (\N{CJK UNIFIED IDEOGRAPH-98DE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26426 (\N{CJK UNIFIED IDEOGRAPH-673A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38738 (\N{CJK UNIFIED IDEOGRAPH-9752}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 34521 (\N{CJK UNIFIED IDEOGRAPH-86D9}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 27773 (\N{CJK UNIFIED IDEOGRAPH-6C7D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 36710 (\N{CJK UNIFIED IDEOGRAPH-8F66}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21345 (\N{CJK UNIFIED IDEOGRAPH-5361}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 29399 (\N{CJK UNIFIED IDEOGRAPH-72D7}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 39532 (\N{CJK UNIFIED IDEOGRAPH-9A6C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from PIL import Image
import requests

img_url = "https://ts1.cn.mm.bing.net/th/id/R-C.30354c0e9024fc7877633f453394054e?rik=uK0BS61YeZy2hA&riu=http%3a%2f%2fwww.yjcf360.com%2fconcept%2f20170920094240_209.jpg&ehk=8GJF3K1unJMf6IDg3103TAHdKoXeVxpd3Z0JV5GkfDo%3d&risl=&pid=ImgRaw&r=0&sres=1&sresct=1"
response = requests.get(img_url, stream=True)
img = Image.open(response.raw)
plt.imshow(img)

# %%
img = transform_test(img)
plt.imshow(im_convert(img))

image = img.to(device).unsqueeze(0)
output = model(image)
_, pred = torch.max(output, 1)
print("Prediction by Model:", (classes[pred.item()]))
# Out:
# Prediction by Model: 飞机

# %%
img_url2 = r"C:\Users\lenovo\Downloads\OIP.jpg"

img2 = Image.open(img_url2)
plt.imshow(img2)

# %%
img2 = transform_test(img2)
plt.imshow(im_convert(img2))

image = img2.to(device).unsqueeze(0)
output = model(image)
_, pred = torch.max(output, 1)
print("Prediction by Model:", (classes[pred.item()]))

# %%
def pre_pic_of_my(img_file_url):
    img = Image.open(img_file_url)

    # 创建一个包含两个子图的图表
    fig, axs = plt.subplots(1, 2, figsize=(10, 5))

    # 显示原始图像
    axs[0].imshow(img)
    axs[0].set_title("原始图像")

    img = transform_test(img)

    # 显示经过 transform 后的图像
    axs[1].imshow(im_convert(img))
    axs[1].set_title("预测处理")

    plt.show()

    image = img.to(device).unsqueeze(0)
    output = model(image)
    _, pred = torch.max(output, 1)
    print("Prediction by Model:", (classes[pred.item()]))


pre_pic_of_my(r"C:\Users\lenovo\Downloads\下载 (2).jpg")

# %%
pre_pic_of_my(r"C:\Users\lenovo\Downloads\下载.jpg")
