# %%
# -*- coding: utf-8 -*-
"""
@File  : resnet.py
@author: FxDr
@Time  : 2023/12/27 20:50
@Description:
"""

import torch
import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion *
                               planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion * planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])


def ResNet50():
    return ResNet(Bottleneck, [3, 4, 6, 3])


def ResNet101():
    return ResNet(Bottleneck, [3, 4, 23, 3])


def ResNet152():
    return ResNet(Bottleneck, [3, 8, 36, 3])


def test():
    net = ResNet18()
    y = net(torch.randn(1, 3, 32, 32))
    print(y.size())

# %%
# -*- coding: utf-8 -*-
"""
@File  : train.py
@author: FxDr
@Time  : 2023/12/27 20:50
@Description: Training script with visualization and evaluation metrics
"""

import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from sklearn.metrics import confusion_matrix
from torch.nn import DataParallel
from torch.optim.lr_scheduler import MultiStepLR
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter



# 设置设备
device = 'cuda' if torch.cuda.is_available() else 'cpu'
best_acc = 0
start_epoch = 0

# 数据预处理
print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

train_dataset = torchvision.datasets.CIFAR10(
    root='/kaggle/input/', train=True, download=True, transform=transform_train)
train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=256, shuffle=True, num_workers=4)

validation_dataset = torchvision.datasets.CIFAR10(
    root='/kaggle/input/', train=False, download=True, transform=transform_test)
validation_loader = torch.utils.data.DataLoader(
    validation_dataset, batch_size=256, shuffle=False, num_workers=4)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# 构建模型
print('==> Building model..')
net = ResNet18()

# 使用DataParallel在多GPU上运行
if torch.cuda.device_count() > 1:
    print("Let's use", torch.cuda.device_count(), "GPUs!")
    net = DataParallel(net)

net = net.to(device)

# 定义损失函数和优化器
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)

# 定义学习率调整策略
scheduler = MultiStepLR(optimizer, milestones=[100, 150], gamma=0.1)

# TensorBoard可视化
writer = SummaryWriter()
net
# Out:
# ==> Building model..
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
    # 训练循环
    for epoch in range(start_epoch, start_epoch + 200):
        net.train()
        train_loss = 0
        correct = 0
        total = 0

        for batch_idx, (inputs, targets) in enumerate(train_loader):
            inputs, targets = inputs.to(device), targets.to(device)

            optimizer.zero_grad()
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

        train_accuracy = 100. * correct / total

        # 生成伪标签并与有标签数据一起训练
        pseudo_loader = torch.utils.data.DataLoader(
            train_dataset, batch_size=128, shuffle=True, num_workers=4)

        for batch_idx, (inputs, targets) in enumerate(pseudo_loader):
            inputs, targets = inputs.to(device), targets.to(device)

            optimizer.zero_grad()
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

        # 验证模型
        net.eval()
        val_loss = 0
        correct = 0
        total = 0

        with torch.no_grad():
            for batch_idx, (inputs, targets) in enumerate(validation_loader):
                inputs, targets = inputs.to(device), targets.to(device)

                outputs = net(inputs)
                loss = criterion(outputs, targets)

                val_loss += loss.item()
                _, predicted = outputs.max(1)
                total += targets.size(0)
                correct += predicted.eq(targets).sum().item()

        val_accuracy = 100. * correct / total

        print("--> Epoch Number : {}".format(epoch + 1),
              " | Training Loss : {}".format(round(train_loss / (batch_idx + 1), 4)),
              " | Validation Loss : {}".format(round(val_loss / (batch_idx + 1), 4)),
              " | Training Accuracy : {}%".format(round(train_accuracy, 2)),
              " | Validation Accuracy : {}%".format(round(val_accuracy, 2)))

        # 写入TensorBoard
        writer.add_scalar('Loss/train', train_loss / (batch_idx + 1), epoch + 1)
        writer.add_scalar('Loss/validation', val_loss / (batch_idx + 1), epoch + 1)
        writer.add_scalar('Accuracy/train', train_accuracy, epoch + 1)
        writer.add_scalar('Accuracy/validation', val_accuracy, epoch + 1)

        # 保存模型
        if val_accuracy > best_acc:
            print('Saving model..')
            state = {
                'net': net.state_dict(),
                'acc': val_accuracy,
                'epoch': epoch,
            }
            torch.save(state, 'best_model.pth')
            best_acc = val_accuracy

        # 调整学习率
        scheduler.step()

    writer.close()  # 关闭TensorBoard写入
# Out:
# --> Epoch Number : 1  | Training Loss : 9.9293  | Validation Loss : 1.4017  | Training Accuracy : 28.92%  | Validation Accuracy : 49.33%
# Saving model..
# --> Epoch Number : 2  | Training Loss : 5.8676  | Validation Loss : 1.0765  | Training Accuracy : 56.93%  | Validation Accuracy : 62.23%
# Saving model..
# --> Epoch Number : 3  | Training Loss : 4.2291  | Validation Loss : 0.929  | Training Accuracy : 69.53%  | Validation Accuracy : 68.02%
# Saving model..
# --> Epoch Number : 4  | Training Loss : 3.1153  | Validation Loss : 0.6285  | Training Accuracy : 77.86%  | Validation Accuracy : 77.55%
# Saving model..
# --> Epoch Number : 5  | Training Loss : 2.5029  | Validation Loss : 0.7586  | Training Accuracy : 82.43%  | Validation Accuracy : 74.26%
# --> Epoch Number : 6  | Training Loss : 2.1466  | Validation Loss : 0.6327  | Training Accuracy : 85.02%  | Validation Accuracy : 78.36%
# Saving model..
# --> Epoch Number : 7  | Training Loss : 1.9817  | Validation Loss : 0.572  | Training Accuracy : 86.03%  | Validation Accuracy : 80.1%
# Saving model..
# --> Epoch Number : 8  | Training Loss : 1.7752  | Validation Loss : 0.5801  | Training Accuracy : 87.38%  | Validation Accuracy : 80.78%
# Saving model..
# --> Epoch Number : 9  | Training Loss : 1.6385  | Validation Loss : 0.5979  | Training Accuracy : 88.53%  | Validation Accuracy : 81.33%
# Saving model..
# --> Epoch Number : 10  | Training Loss : 1.5599  | Validation Loss : 0.6967  | Training Accuracy : 89.18%  | Validation Accuracy : 78.31%
# --> Epoch Number : 11  | Training Loss : 1.5104  | Validation Loss : 0.5388  | Training Accuracy : 89.39%  | Validation Accuracy : 81.92%
# Saving model..
# --> Epoch Number : 12  | Training Loss : 1.4444  | Validation Loss : 0.6864  | Training Accuracy : 89.82%  | Validation Accuracy : 77.85%
# --> Epoch Number : 13  | Training Loss : 1.3645  | Validation Loss : 0.7138  | Training Accuracy : 90.42%  | Validation Accuracy : 76.58%
# --> Epoch Number : 14  | Training Loss : 1.3344  | Validation Loss : 0.4704  | Training Accuracy : 90.5%  | Validation Accuracy : 84.6%
# Saving model..
# --> Epoch Number : 15  | Training Loss : 1.3022  | Validation Loss : 0.6645  | Training Accuracy : 90.73%  | Validation Accuracy : 77.91%
# --> Epoch Number : 16  | Training Loss : 1.2554  | Validation Loss : 0.5345  | Training Accuracy : 91.2%  | Validation Accuracy : 82.96%
# --> Epoch Number : 17  | Training Loss : 1.2274  | Validation Loss : 0.6776  | Training Accuracy : 91.38%  | Validation Accuracy : 77.95%
# --> Epoch Number : 18  | Training Loss : 1.2118  | Validation Loss : 0.7085  | Training Accuracy : 91.47%  | Validation Accuracy : 78.28%
# --> Epoch Number : 19  | Training Loss : 1.1713  | Validation Loss : 0.446  | Training Accuracy : 91.82%  | Validation Accuracy : 85.4%
# Saving model..
# --> Epoch Number : 20  | Training Loss : 1.1447  | Validation Loss : 0.4908  | Training Accuracy : 92.09%  | Validation Accuracy : 83.7%
# --> Epoch Number : 21  | Training Loss : 1.1439  | Validation Loss : 0.4672  | Training Accuracy : 92.06%  | Validation Accuracy : 84.52%
# --> Epoch Number : 22  | Training Loss : 1.1227  | Validation Loss : 0.6321  | Training Accuracy : 92.11%  | Validation Accuracy : 79.71%
# --> Epoch Number : 23  | Training Loss : 1.1202  | Validation Loss : 0.495  | Training Accuracy : 92.26%  | Validation Accuracy : 84.03%
# --> Epoch Number : 24  | Training Loss : 1.1123  | Validation Loss : 0.7783  | Training Accuracy : 92.25%  | Validation Accuracy : 77.84%
# --> Epoch Number : 25  | Training Loss : 1.0991  | Validation Loss : 0.6803  | Training Accuracy : 92.43%  | Validation Accuracy : 78.43%
# --> Epoch Number : 26  | Training Loss : 1.1061  | Validation Loss : 0.4444  | Training Accuracy : 92.18%  | Validation Accuracy : 85.05%
# --> Epoch Number : 27  | Training Loss : 1.063  | Validation Loss : 0.4642  | Training Accuracy : 92.57%  | Validation Accuracy : 84.69%
# --> Epoch Number : 28  | Training Loss : 1.0756  | Validation Loss : 0.4602  | Training Accuracy : 92.4%  | Validation Accuracy : 84.93%
# --> Epoch Number : 29  | Training Loss : 1.0559  | Validation Loss : 0.4174  | Training Accuracy : 92.62%  | Validation Accuracy : 85.74%
# Saving model..
# --> Epoch Number : 30  | Training Loss : 1.0447  | Validation Loss : 0.5464  | Training Accuracy : 92.79%  | Validation Accuracy : 82.82%
# --> Epoch Number : 31  | Training Loss : 1.055  | Validation Loss : 0.5515  | Training Accuracy : 92.68%  | Validation Accuracy : 82.91%
# --> Epoch Number : 32  | Training Loss : 1.0167  | Validation Loss : 0.4993  | Training Accuracy : 92.91%  | Validation Accuracy : 83.76%
# --> Epoch Number : 33  | Training Loss : 1.0073  | Validation Loss : 0.5393  | Training Accuracy : 93.03%  | Validation Accuracy : 82.18%
# --> Epoch Number : 34  | Training Loss : 1.0006  | Validation Loss : 0.5213  | Training Accuracy : 93.0%  | Validation Accuracy : 82.9%
# --> Epoch Number : 35  | Training Loss : 0.9891  | Validation Loss : 0.4206  | Training Accuracy : 93.11%  | Validation Accuracy : 85.51%
# --> Epoch Number : 36  | Training Loss : 1.0101  | Validation Loss : 0.5261  | Training Accuracy : 92.9%  | Validation Accuracy : 82.63%
# --> Epoch Number : 37  | Training Loss : 1.0172  | Validation Loss : 0.5002  | Training Accuracy : 92.87%  | Validation Accuracy : 83.32%
# --> Epoch Number : 38  | Training Loss : 1.0179  | Validation Loss : 0.489  | Training Accuracy : 93.0%  | Validation Accuracy : 83.2%
# --> Epoch Number : 39  | Training Loss : 0.984  | Validation Loss : 0.4683  | Training Accuracy : 93.16%  | Validation Accuracy : 84.27%
# --> Epoch Number : 40  | Training Loss : 0.9604  | Validation Loss : 0.5327  | Training Accuracy : 93.33%  | Validation Accuracy : 82.49%
# --> Epoch Number : 41  | Training Loss : 1.0284  | Validation Loss : 0.7577  | Training Accuracy : 92.75%  | Validation Accuracy : 76.52%
# --> Epoch Number : 42  | Training Loss : 0.9863  | Validation Loss : 0.6914  | Training Accuracy : 93.04%  | Validation Accuracy : 78.76%
# --> Epoch Number : 43  | Training Loss : 0.997  | Validation Loss : 0.6533  | Training Accuracy : 93.16%  | Validation Accuracy : 78.62%
# --> Epoch Number : 44  | Training Loss : 0.9863  | Validation Loss : 0.7107  | Training Accuracy : 93.06%  | Validation Accuracy : 78.51%
# --> Epoch Number : 45  | Training Loss : 0.9948  | Validation Loss : 0.9095  | Training Accuracy : 93.09%  | Validation Accuracy : 75.4%
# --> Epoch Number : 46  | Training Loss : 0.9793  | Validation Loss : 0.5266  | Training Accuracy : 93.1%  | Validation Accuracy : 83.24%
# --> Epoch Number : 47  | Training Loss : 0.9602  | Validation Loss : 0.4987  | Training Accuracy : 93.37%  | Validation Accuracy : 83.62%
# --> Epoch Number : 48  | Training Loss : 0.9702  | Validation Loss : 0.4584  | Training Accuracy : 93.2%  | Validation Accuracy : 84.66%
# --> Epoch Number : 49  | Training Loss : 0.9797  | Validation Loss : 0.7338  | Training Accuracy : 93.11%  | Validation Accuracy : 75.94%
# --> Epoch Number : 50  | Training Loss : 0.9834  | Validation Loss : 0.4788  | Training Accuracy : 93.16%  | Validation Accuracy : 84.35%
# --> Epoch Number : 51  | Training Loss : 0.9366  | Validation Loss : 0.4642  | Training Accuracy : 93.46%  | Validation Accuracy : 84.76%
# --> Epoch Number : 52  | Training Loss : 0.9562  | Validation Loss : 0.6154  | Training Accuracy : 93.37%  | Validation Accuracy : 80.98%
# --> Epoch Number : 53  | Training Loss : 0.96  | Validation Loss : 0.4095  | Training Accuracy : 93.38%  | Validation Accuracy : 86.15%
# Saving model..
# --> Epoch Number : 54  | Training Loss : 0.9559  | Validation Loss : 0.4912  | Training Accuracy : 93.3%  | Validation Accuracy : 83.79%
# --> Epoch Number : 55  | Training Loss : 0.9645  | Validation Loss : 0.4388  | Training Accuracy : 93.35%  | Validation Accuracy : 85.56%
# --> Epoch Number : 56  | Training Loss : 0.9628  | Validation Loss : 0.5238  | Training Accuracy : 93.24%  | Validation Accuracy : 83.01%
# --> Epoch Number : 57  | Training Loss : 0.9545  | Validation Loss : 0.6928  | Training Accuracy : 93.35%  | Validation Accuracy : 78.52%
# --> Epoch Number : 58  | Training Loss : 0.9584  | Validation Loss : 0.448  | Training Accuracy : 93.36%  | Validation Accuracy : 84.81%
# --> Epoch Number : 59  | Training Loss : 0.949  | Validation Loss : 0.4413  | Training Accuracy : 93.32%  | Validation Accuracy : 85.5%
# --> Epoch Number : 60  | Training Loss : 0.9539  | Validation Loss : 0.4235  | Training Accuracy : 93.34%  | Validation Accuracy : 86.27%
# Saving model..
# --> Epoch Number : 61  | Training Loss : 0.958  | Validation Loss : 0.6091  | Training Accuracy : 93.32%  | Validation Accuracy : 80.63%
# --> Epoch Number : 62  | Training Loss : 0.9378  | Validation Loss : 0.5081  | Training Accuracy : 93.36%  | Validation Accuracy : 83.23%
# --> Epoch Number : 63  | Training Loss : 0.9341  | Validation Loss : 0.6158  | Training Accuracy : 93.41%  | Validation Accuracy : 80.67%
# --> Epoch Number : 64  | Training Loss : 0.9538  | Validation Loss : 0.5003  | Training Accuracy : 93.36%  | Validation Accuracy : 84.35%
# --> Epoch Number : 65  | Training Loss : 0.9382  | Validation Loss : 0.5215  | Training Accuracy : 93.55%  | Validation Accuracy : 83.59%
# --> Epoch Number : 66  | Training Loss : 0.9536  | Validation Loss : 0.5608  | Training Accuracy : 93.39%  | Validation Accuracy : 83.01%
# --> Epoch Number : 67  | Training Loss : 0.9202  | Validation Loss : 0.5009  | Training Accuracy : 93.61%  | Validation Accuracy : 84.03%
# --> Epoch Number : 68  | Training Loss : 0.9537  | Validation Loss : 0.4544  | Training Accuracy : 93.35%  | Validation Accuracy : 84.57%
# --> Epoch Number : 69  | Training Loss : 0.9211  | Validation Loss : 0.5729  | Training Accuracy : 93.55%  | Validation Accuracy : 81.66%
# --> Epoch Number : 70  | Training Loss : 0.9417  | Validation Loss : 0.5383  | Training Accuracy : 93.39%  | Validation Accuracy : 82.7%
# --> Epoch Number : 71  | Training Loss : 0.9375  | Validation Loss : 0.4745  | Training Accuracy : 93.58%  | Validation Accuracy : 84.75%
# --> Epoch Number : 72  | Training Loss : 0.9305  | Validation Loss : 0.4531  | Training Accuracy : 93.47%  | Validation Accuracy : 85.27%
# --> Epoch Number : 73  | Training Loss : 0.9234  | Validation Loss : 0.5129  | Training Accuracy : 93.73%  | Validation Accuracy : 83.02%
# --> Epoch Number : 74  | Training Loss : 0.9292  | Validation Loss : 0.7641  | Training Accuracy : 93.45%  | Validation Accuracy : 77.16%
# --> Epoch Number : 75  | Training Loss : 0.9113  | Validation Loss : 0.481  | Training Accuracy : 93.67%  | Validation Accuracy : 83.64%
# --> Epoch Number : 76  | Training Loss : 0.9383  | Validation Loss : 0.5103  | Training Accuracy : 93.55%  | Validation Accuracy : 82.9%
# --> Epoch Number : 77  | Training Loss : 0.9159  | Validation Loss : 0.4799  | Training Accuracy : 93.64%  | Validation Accuracy : 84.41%
# --> Epoch Number : 78  | Training Loss : 0.9166  | Validation Loss : 0.5122  | Training Accuracy : 93.65%  | Validation Accuracy : 83.49%
# --> Epoch Number : 79  | Training Loss : 0.9421  | Validation Loss : 0.5921  | Training Accuracy : 93.47%  | Validation Accuracy : 81.03%
# --> Epoch Number : 80  | Training Loss : 0.91  | Validation Loss : 0.4379  | Training Accuracy : 93.58%  | Validation Accuracy : 86.06%
# --> Epoch Number : 81  | Training Loss : 0.909  | Validation Loss : 0.5413  | Training Accuracy : 93.67%  | Validation Accuracy : 82.15%
# --> Epoch Number : 82  | Training Loss : 0.8992  | Validation Loss : 0.5625  | Training Accuracy : 93.82%  | Validation Accuracy : 82.41%
# --> Epoch Number : 83  | Training Loss : 0.9521  | Validation Loss : 0.5218  | Training Accuracy : 93.34%  | Validation Accuracy : 82.75%
# --> Epoch Number : 84  | Training Loss : 0.9001  | Validation Loss : 0.4903  | Training Accuracy : 93.68%  | Validation Accuracy : 84.66%
# --> Epoch Number : 85  | Training Loss : 0.9364  | Validation Loss : 0.488  | Training Accuracy : 93.41%  | Validation Accuracy : 84.94%
# --> Epoch Number : 86  | Training Loss : 0.9235  | Validation Loss : 0.4646  | Training Accuracy : 93.56%  | Validation Accuracy : 85.13%
# --> Epoch Number : 87  | Training Loss : 0.9137  | Validation Loss : 0.6316  | Training Accuracy : 93.67%  | Validation Accuracy : 80.86%
# --> Epoch Number : 88  | Training Loss : 0.9327  | Validation Loss : 0.4587  | Training Accuracy : 93.53%  | Validation Accuracy : 84.77%
# --> Epoch Number : 89  | Training Loss : 0.9366  | Validation Loss : 0.4374  | Training Accuracy : 93.44%  | Validation Accuracy : 85.34%
# --> Epoch Number : 90  | Training Loss : 0.9245  | Validation Loss : 0.5009  | Training Accuracy : 93.58%  | Validation Accuracy : 83.28%
# --> Epoch Number : 91  | Training Loss : 0.9149  | Validation Loss : 0.9865  | Training Accuracy : 93.7%  | Validation Accuracy : 73.85%
# --> Epoch Number : 92  | Training Loss : 0.9078  | Validation Loss : 0.4285  | Training Accuracy : 93.6%  | Validation Accuracy : 85.65%
# --> Epoch Number : 93  | Training Loss : 0.9012  | Validation Loss : 0.5093  | Training Accuracy : 93.69%  | Validation Accuracy : 83.53%
# --> Epoch Number : 94  | Training Loss : 0.9265  | Validation Loss : 0.4643  | Training Accuracy : 93.56%  | Validation Accuracy : 84.69%
# --> Epoch Number : 95  | Training Loss : 0.9336  | Validation Loss : 0.4851  | Training Accuracy : 93.52%  | Validation Accuracy : 84.07%
# --> Epoch Number : 96  | Training Loss : 0.8949  | Validation Loss : 0.5349  | Training Accuracy : 93.79%  | Validation Accuracy : 82.7%
# --> Epoch Number : 97  | Training Loss : 0.927  | Validation Loss : 0.4691  | Training Accuracy : 93.51%  | Validation Accuracy : 84.58%
# --> Epoch Number : 98  | Training Loss : 0.9379  | Validation Loss : 0.4499  | Training Accuracy : 93.48%  | Validation Accuracy : 85.01%
# --> Epoch Number : 99  | Training Loss : 0.9263  | Validation Loss : 0.4229  | Training Accuracy : 93.52%  | Validation Accuracy : 85.78%
# --> Epoch Number : 100  | Training Loss : 0.8977  | Validation Loss : 0.5296  | Training Accuracy : 93.76%  | Validation Accuracy : 82.86%
# --> Epoch Number : 101  | Training Loss : 0.8418  | Validation Loss : 0.1895  | Training Accuracy : 94.31%  | Validation Accuracy : 93.7%
# Saving model..
# --> Epoch Number : 102  | Training Loss : 0.4214  | Validation Loss : 0.1844  | Training Accuracy : 97.19%  | Validation Accuracy : 93.92%
# Saving model..
# --> Epoch Number : 103  | Training Loss : 0.3094  | Validation Loss : 0.1848  | Training Accuracy : 97.93%  | Validation Accuracy : 94.1%
# Saving model..
# --> Epoch Number : 104  | Training Loss : 0.2404  | Validation Loss : 0.186  | Training Accuracy : 98.39%  | Validation Accuracy : 94.16%
# Saving model..
# --> Epoch Number : 105  | Training Loss : 0.1834  | Validation Loss : 0.1963  | Training Accuracy : 98.83%  | Validation Accuracy : 94.24%
# Saving model..
# --> Epoch Number : 106  | Training Loss : 0.1473  | Validation Loss : 0.2131  | Training Accuracy : 99.05%  | Validation Accuracy : 93.86%
# --> Epoch Number : 107  | Training Loss : 0.1281  | Validation Loss : 0.2001  | Training Accuracy : 99.21%  | Validation Accuracy : 94.21%
# --> Epoch Number : 108  | Training Loss : 0.1116  | Validation Loss : 0.2045  | Training Accuracy : 99.32%  | Validation Accuracy : 94.28%
# Saving model..
# --> Epoch Number : 109  | Training Loss : 0.0976  | Validation Loss : 0.2187  | Training Accuracy : 99.42%  | Validation Accuracy : 94.03%
# --> Epoch Number : 110  | Training Loss : 0.0875  | Validation Loss : 0.2113  | Training Accuracy : 99.52%  | Validation Accuracy : 94.01%
# --> Epoch Number : 111  | Training Loss : 0.0841  | Validation Loss : 0.2232  | Training Accuracy : 99.5%  | Validation Accuracy : 93.94%
# --> Epoch Number : 112  | Training Loss : 0.0784  | Validation Loss : 0.2161  | Training Accuracy : 99.59%  | Validation Accuracy : 94.17%
# --> Epoch Number : 113  | Training Loss : 0.0726  | Validation Loss : 0.2221  | Training Accuracy : 99.58%  | Validation Accuracy : 94.17%
# --> Epoch Number : 114  | Training Loss : 0.0709  | Validation Loss : 0.2389  | Training Accuracy : 99.59%  | Validation Accuracy : 93.23%
# --> Epoch Number : 115  | Training Loss : 0.0666  | Validation Loss : 0.24  | Training Accuracy : 99.65%  | Validation Accuracy : 93.72%
# --> Epoch Number : 116  | Training Loss : 0.0684  | Validation Loss : 0.2453  | Training Accuracy : 99.62%  | Validation Accuracy : 93.43%
# --> Epoch Number : 117  | Training Loss : 0.0809  | Validation Loss : 0.2404  | Training Accuracy : 99.52%  | Validation Accuracy : 93.61%
# --> Epoch Number : 118  | Training Loss : 0.0792  | Validation Loss : 0.2417  | Training Accuracy : 99.52%  | Validation Accuracy : 93.3%
# --> Epoch Number : 119  | Training Loss : 0.0842  | Validation Loss : 0.2489  | Training Accuracy : 99.45%  | Validation Accuracy : 93.18%
# --> Epoch Number : 120  | Training Loss : 0.0762  | Validation Loss : 0.2382  | Training Accuracy : 99.56%  | Validation Accuracy : 93.28%
# --> Epoch Number : 121  | Training Loss : 0.0889  | Validation Loss : 0.2422  | Training Accuracy : 99.47%  | Validation Accuracy : 93.17%
# --> Epoch Number : 122  | Training Loss : 0.0852  | Validation Loss : 0.2704  | Training Accuracy : 99.52%  | Validation Accuracy : 92.85%
# --> Epoch Number : 123  | Training Loss : 0.085  | Validation Loss : 0.2793  | Training Accuracy : 99.5%  | Validation Accuracy : 92.57%
# --> Epoch Number : 124  | Training Loss : 0.098  | Validation Loss : 0.2426  | Training Accuracy : 99.41%  | Validation Accuracy : 93.13%
# --> Epoch Number : 125  | Training Loss : 0.0882  | Validation Loss : 0.239  | Training Accuracy : 99.49%  | Validation Accuracy : 93.21%
# --> Epoch Number : 126  | Training Loss : 0.0992  | Validation Loss : 0.2733  | Training Accuracy : 99.4%  | Validation Accuracy : 92.38%
# --> Epoch Number : 127  | Training Loss : 0.0997  | Validation Loss : 0.2864  | Training Accuracy : 99.4%  | Validation Accuracy : 91.91%
# --> Epoch Number : 128  | Training Loss : 0.1134  | Validation Loss : 0.2679  | Training Accuracy : 99.31%  | Validation Accuracy : 92.41%
# --> Epoch Number : 129  | Training Loss : 0.1007  | Validation Loss : 0.265  | Training Accuracy : 99.4%  | Validation Accuracy : 92.66%
# --> Epoch Number : 130  | Training Loss : 0.0977  | Validation Loss : 0.2856  | Training Accuracy : 99.43%  | Validation Accuracy : 92.45%
# --> Epoch Number : 131  | Training Loss : 0.1048  | Validation Loss : 0.3184  | Training Accuracy : 99.37%  | Validation Accuracy : 91.12%
# --> Epoch Number : 132  | Training Loss : 0.1163  | Validation Loss : 0.3073  | Training Accuracy : 99.28%  | Validation Accuracy : 91.34%
# --> Epoch Number : 133  | Training Loss : 0.1216  | Validation Loss : 0.2842  | Training Accuracy : 99.23%  | Validation Accuracy : 92.24%
# --> Epoch Number : 134  | Training Loss : 0.1125  | Validation Loss : 0.2768  | Training Accuracy : 99.33%  | Validation Accuracy : 92.12%
# --> Epoch Number : 135  | Training Loss : 0.115  | Validation Loss : 0.2716  | Training Accuracy : 99.31%  | Validation Accuracy : 92.03%
# --> Epoch Number : 136  | Training Loss : 0.1015  | Validation Loss : 0.2712  | Training Accuracy : 99.38%  | Validation Accuracy : 92.03%
# --> Epoch Number : 137  | Training Loss : 0.1125  | Validation Loss : 0.275  | Training Accuracy : 99.32%  | Validation Accuracy : 92.41%
# --> Epoch Number : 138  | Training Loss : 0.1198  | Validation Loss : 0.2897  | Training Accuracy : 99.29%  | Validation Accuracy : 91.81%
# --> Epoch Number : 139  | Training Loss : 0.1085  | Validation Loss : 0.258  | Training Accuracy : 99.38%  | Validation Accuracy : 92.55%
# --> Epoch Number : 140  | Training Loss : 0.1083  | Validation Loss : 0.3154  | Training Accuracy : 99.37%  | Validation Accuracy : 91.8%
# --> Epoch Number : 141  | Training Loss : 0.1014  | Validation Loss : 0.293  | Training Accuracy : 99.42%  | Validation Accuracy : 91.98%
# --> Epoch Number : 142  | Training Loss : 0.0995  | Validation Loss : 0.3201  | Training Accuracy : 99.41%  | Validation Accuracy : 91.25%
# --> Epoch Number : 143  | Training Loss : 0.1131  | Validation Loss : 0.2541  | Training Accuracy : 99.29%  | Validation Accuracy : 92.9%
# --> Epoch Number : 144  | Training Loss : 0.1026  | Validation Loss : 0.2839  | Training Accuracy : 99.39%  | Validation Accuracy : 92.06%
# --> Epoch Number : 145  | Training Loss : 0.1128  | Validation Loss : 0.2889  | Training Accuracy : 99.33%  | Validation Accuracy : 91.65%
# --> Epoch Number : 146  | Training Loss : 0.1083  | Validation Loss : 0.2763  | Training Accuracy : 99.31%  | Validation Accuracy : 92.3%
# --> Epoch Number : 147  | Training Loss : 0.1182  | Validation Loss : 0.2907  | Training Accuracy : 99.28%  | Validation Accuracy : 91.73%
# --> Epoch Number : 148  | Training Loss : 0.1143  | Validation Loss : 0.2917  | Training Accuracy : 99.31%  | Validation Accuracy : 92.16%
# --> Epoch Number : 149  | Training Loss : 0.1141  | Validation Loss : 0.2921  | Training Accuracy : 99.29%  | Validation Accuracy : 91.93%
# --> Epoch Number : 150  | Training Loss : 0.1095  | Validation Loss : 0.2995  | Training Accuracy : 99.37%  | Validation Accuracy : 92.07%
# --> Epoch Number : 151  | Training Loss : 0.1238  | Validation Loss : 0.2044  | Training Accuracy : 99.28%  | Validation Accuracy : 94.43%
# Saving model..
# --> Epoch Number : 152  | Training Loss : 0.0463  | Validation Loss : 0.1949  | Training Accuracy : 99.78%  | Validation Accuracy : 94.5%
# Saving model..
# --> Epoch Number : 153  | Training Loss : 0.0313  | Validation Loss : 0.1921  | Training Accuracy : 99.89%  | Validation Accuracy : 94.85%
# Saving model..
# --> Epoch Number : 154  | Training Loss : 0.0246  | Validation Loss : 0.1884  | Training Accuracy : 99.93%  | Validation Accuracy : 94.85%
# --> Epoch Number : 155  | Training Loss : 0.0216  | Validation Loss : 0.1881  | Training Accuracy : 99.93%  | Validation Accuracy : 94.99%
# Saving model..
# --> Epoch Number : 156  | Training Loss : 0.0178  | Validation Loss : 0.1898  | Training Accuracy : 99.96%  | Validation Accuracy : 94.89%
# --> Epoch Number : 157  | Training Loss : 0.0161  | Validation Loss : 0.1908  | Training Accuracy : 99.96%  | Validation Accuracy : 94.92%
# --> Epoch Number : 158  | Training Loss : 0.0146  | Validation Loss : 0.1921  | Training Accuracy : 99.98%  | Validation Accuracy : 95.02%
# Saving model..
# --> Epoch Number : 159  | Training Loss : 0.0141  | Validation Loss : 0.1934  | Training Accuracy : 99.98%  | Validation Accuracy : 94.91%
# --> Epoch Number : 160  | Training Loss : 0.0132  | Validation Loss : 0.1885  | Training Accuracy : 99.98%  | Validation Accuracy : 95.05%
# Saving model..
# --> Epoch Number : 161  | Training Loss : 0.0126  | Validation Loss : 0.1925  | Training Accuracy : 99.98%  | Validation Accuracy : 95.03%
# --> Epoch Number : 162  | Training Loss : 0.0125  | Validation Loss : 0.19  | Training Accuracy : 99.98%  | Validation Accuracy : 94.9%
# --> Epoch Number : 163  | Training Loss : 0.0112  | Validation Loss : 0.1885  | Training Accuracy : 99.99%  | Validation Accuracy : 95.06%
# Saving model..
# --> Epoch Number : 164  | Training Loss : 0.0109  | Validation Loss : 0.1895  | Training Accuracy : 99.99%  | Validation Accuracy : 94.91%
# --> Epoch Number : 165  | Training Loss : 0.0103  | Validation Loss : 0.1882  | Training Accuracy : 99.99%  | Validation Accuracy : 95.18%
# Saving model..
# --> Epoch Number : 166  | Training Loss : 0.0101  | Validation Loss : 0.1893  | Training Accuracy : 99.99%  | Validation Accuracy : 95.07%
# --> Epoch Number : 167  | Training Loss : 0.0102  | Validation Loss : 0.1892  | Training Accuracy : 99.99%  | Validation Accuracy : 95.07%
# --> Epoch Number : 168  | Training Loss : 0.0096  | Validation Loss : 0.1893  | Training Accuracy : 99.99%  | Validation Accuracy : 95.1%
# --> Epoch Number : 169  | Training Loss : 0.0092  | Validation Loss : 0.1854  | Training Accuracy : 100.0%  | Validation Accuracy : 95.09%
# --> Epoch Number : 170  | Training Loss : 0.0091  | Validation Loss : 0.1865  | Training Accuracy : 100.0%  | Validation Accuracy : 95.02%
# --> Epoch Number : 171  | Training Loss : 0.0086  | Validation Loss : 0.1837  | Training Accuracy : 100.0%  | Validation Accuracy : 95.22%
# Saving model..
# --> Epoch Number : 172  | Training Loss : 0.0096  | Validation Loss : 0.1846  | Training Accuracy : 99.99%  | Validation Accuracy : 95.2%
# --> Epoch Number : 173  | Training Loss : 0.0085  | Validation Loss : 0.1831  | Training Accuracy : 99.99%  | Validation Accuracy : 95.13%
# --> Epoch Number : 174  | Training Loss : 0.009  | Validation Loss : 0.185  | Training Accuracy : 99.99%  | Validation Accuracy : 95.09%
# --> Epoch Number : 175  | Training Loss : 0.0084  | Validation Loss : 0.1836  | Training Accuracy : 99.99%  | Validation Accuracy : 95.1%
# --> Epoch Number : 176  | Training Loss : 0.0078  | Validation Loss : 0.1836  | Training Accuracy : 100.0%  | Validation Accuracy : 95.16%
# --> Epoch Number : 177  | Training Loss : 0.0082  | Validation Loss : 0.1853  | Training Accuracy : 100.0%  | Validation Accuracy : 95.18%
# --> Epoch Number : 178  | Training Loss : 0.0086  | Validation Loss : 0.1864  | Training Accuracy : 100.0%  | Validation Accuracy : 95.22%
# --> Epoch Number : 179  | Training Loss : 0.0077  | Validation Loss : 0.1853  | Training Accuracy : 100.0%  | Validation Accuracy : 95.03%
# --> Epoch Number : 180  | Training Loss : 0.0088  | Validation Loss : 0.184  | Training Accuracy : 99.99%  | Validation Accuracy : 95.14%
# --> Epoch Number : 181  | Training Loss : 0.0076  | Validation Loss : 0.1833  | Training Accuracy : 100.0%  | Validation Accuracy : 95.2%
# --> Epoch Number : 182  | Training Loss : 0.0079  | Validation Loss : 0.1839  | Training Accuracy : 100.0%  | Validation Accuracy : 95.09%
# --> Epoch Number : 183  | Training Loss : 0.0081  | Validation Loss : 0.1816  | Training Accuracy : 99.99%  | Validation Accuracy : 95.15%
# --> Epoch Number : 184  | Training Loss : 0.0079  | Validation Loss : 0.1819  | Training Accuracy : 100.0%  | Validation Accuracy : 95.14%
# --> Epoch Number : 185  | Training Loss : 0.0074  | Validation Loss : 0.1807  | Training Accuracy : 100.0%  | Validation Accuracy : 95.24%
# Saving model..
# --> Epoch Number : 186  | Training Loss : 0.0074  | Validation Loss : 0.1839  | Training Accuracy : 100.0%  | Validation Accuracy : 95.11%
# --> Epoch Number : 187  | Training Loss : 0.0074  | Validation Loss : 0.1812  | Training Accuracy : 100.0%  | Validation Accuracy : 95.22%
# --> Epoch Number : 188  | Training Loss : 0.0075  | Validation Loss : 0.1828  | Training Accuracy : 100.0%  | Validation Accuracy : 95.23%
# --> Epoch Number : 189  | Training Loss : 0.0078  | Validation Loss : 0.1827  | Training Accuracy : 100.0%  | Validation Accuracy : 95.2%
# --> Epoch Number : 190  | Training Loss : 0.0076  | Validation Loss : 0.1831  | Training Accuracy : 100.0%  | Validation Accuracy : 95.18%
# --> Epoch Number : 191  | Training Loss : 0.0074  | Validation Loss : 0.1821  | Training Accuracy : 100.0%  | Validation Accuracy : 95.23%
# --> Epoch Number : 192  | Training Loss : 0.0077  | Validation Loss : 0.1827  | Training Accuracy : 100.0%  | Validation Accuracy : 95.23%
# --> Epoch Number : 193  | Training Loss : 0.0074  | Validation Loss : 0.1826  | Training Accuracy : 100.0%  | Validation Accuracy : 95.2%
# --> Epoch Number : 194  | Training Loss : 0.0073  | Validation Loss : 0.1811  | Training Accuracy : 100.0%  | Validation Accuracy : 95.3%
# Saving model..
# --> Epoch Number : 195  | Training Loss : 0.0074  | Validation Loss : 0.1793  | Training Accuracy : 100.0%  | Validation Accuracy : 95.26%
# --> Epoch Number : 196  | Training Loss : 0.0074  | Validation Loss : 0.1802  | Training Accuracy : 100.0%  | Validation Accuracy : 95.24%
# --> Epoch Number : 197  | Training Loss : 0.0076  | Validation Loss : 0.1808  | Training Accuracy : 100.0%  | Validation Accuracy : 95.21%
# --> Epoch Number : 198  | Training Loss : 0.0073  | Validation Loss : 0.1788  | Training Accuracy : 100.0%  | Validation Accuracy : 95.28%
# --> Epoch Number : 199  | Training Loss : 0.0072  | Validation Loss : 0.1832  | Training Accuracy : 100.0%  | Validation Accuracy : 95.4%
# Saving model..
# --> Epoch Number : 200  | Training Loss : 0.0074  | Validation Loss : 0.1786  | Training Accuracy : 100.0%  | Validation Accuracy : 95.25%

# %%
# !zip -r runs.zip runs
# Out:
# updating: runs/ (stored 0%)
# updating: runs/Dec28_15-01-42_dd2b719c8cad/ (stored 0%)
# updating: runs/Dec28_15-01-42_dd2b719c8cad/events.out.tfevents.1703775702.dd2b719c8cad.42.0 (deflated 71%)

# %%
# 加载最好的模型并进行测试
print("Loading the best model for testing..")
best_model = ResNet18()
best_model = best_model.to(device)
best_model.load_state_dict(torch.load('best_model.pth')['net'])
best_model.eval()

test_loss = 0
correct = 0
total = 0

all_preds = []
all_targets = []

with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(validation_loader):
        inputs, targets = inputs.to(device), targets.to(device)

        outputs = best_model(inputs)
        loss = criterion(outputs, targets)

        test_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

        all_preds.extend(predicted.cpu().numpy())
        all_targets.extend(targets.cpu().numpy())

test_accuracy = 100. * correct / total
print('Test Accuracy: {:.2f}%'.format(test_accuracy))
# Out:
# Loading the best model for testing..
# Test Accuracy: 95.40%

# %%
# 计算混淆矩阵
cm = confusion_matrix(all_targets, all_preds)

# 可视化混淆矩阵
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=classes, yticklabels=classes)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

print("Training finished.")
# Out:
# Training finished.
